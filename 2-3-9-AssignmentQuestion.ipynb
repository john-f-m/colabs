# %% [markdown]
# <a href="https://colab.research.google.com/github/john-f-m/colabs/blob/master/2-3-9-AssignmentQuestion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create a CNN to classify Cifar-10
#
# Learn about Cifar-10 here: https://www.cs.toronto.edu/~kriz/cifar.html
#
# In class you saw how to build a Convolutional Neural Network that classified Fashion MNIST. Take what you learned to build a CNN that recognizes the 10 classes of CIFAR. It will be a similar network, but there are some key differences you'll need to take into account.
#
# First, while MNIST were 28x28 monochome images (1 color channel), CIFAR are 32x32 color images (3 color channels).
#
# Second, MNIST images are simple, containing just the object, centered in the image, with no background. CIFAR ones can have the object with a background -- for example airplanes might have a cloudy sky behind them! As such you should expect your accuracy to be a bit lower.
#
# We start by setting up the problem for you.

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 20s 0us/step

# %% [markdown]
# We then definte some of the model for you but leave most of it for you to fill in!
#
# *A hint: your model may want to learn some high level features and then classify them.*

# %%
FIRST_LAYER = tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(32, 32, 3))
HIDDEN_LAYER_TYPE_1 = tf.keras.layers.MaxPooling2D(2, 2)
HIDDEN_LAYER_TYPE_2 = tf.keras.layers.Conv2D(64, (3,3), activation='relu')
HIDDEN_LAYER_TYPE_3 = tf.keras.layers.MaxPooling2D(2,2)
HIDDEN_LAYER_TYPE_4 = tf.keras.layers.Flatten()
HIDDEN_LAYER_TYPE_5 = tf.keras.layers.Dense(20, activation='relu')
LAST_LAYER = tf.keras.layers.Dense(10, activation='softmax')

model = models.Sequential([
       FIRST_LAYER,
       HIDDEN_LAYER_TYPE_1,
       HIDDEN_LAYER_TYPE_2,
       HIDDEN_LAYER_TYPE_3,
       HIDDEN_LAYER_TYPE_4,
       HIDDEN_LAYER_TYPE_5,
       LAST_LAYER,
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# You then need to define loss function. And you can then train your model. Once training is done you'll see a plot of training and validation accuracy. You'll know you have a reasonable model with a reasonable loss funciton if your final training accuracy ends up in the 70s (or possibly higher).
#
# *A hint: your model may want to learn different categories.*

# %%
LOSS = 'sparse_categorical_crossentropy'
NUM_EPOCHS = 20 #You can change this value if you like to experiment with it to get better accuracy

# Compile the model
model.compile(optimizer='sgd',
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.2072 - loss: 2.1503 - val_accuracy: 0.3425 - val_loss: 1.8383
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.4092 - loss: 1.6514 - val_accuracy: 0.4696 - val_loss: 1.4844
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.4755 - loss: 1.4612 - val_accuracy: 0.4967 - val_loss: 1.4117
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.5097 - loss: 1.3683 - val_accuracy: 0.5218 - val_loss: 1.3448
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.5405 - loss: 1.2962 - val_accuracy: 0.5333 - val_loss: 1.3590
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5698 - loss: 1.2287 - val_accuracy: 0.5632 - val_loss: 1.2315
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5950 - loss: 1.1578 - val_accuracy: 0.5924 - val_loss: 1.1590
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6112 - loss: 1.1145 - val_accuracy: 0.6089 - val_loss: 1.1276
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6244 - loss: 1.0754 - val_accuracy: 0.5586 - val_loss: 1.2660
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6447 - loss: 1.0242 - val_accuracy: 0.6144 - val_loss: 1.1253
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6555 - loss: 0.9898 - val_accuracy: 0.6324 - val_loss: 1.0732
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6658 - loss: 0.9514 - val_accuracy: 0.6429 - val_loss: 1.0320
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6791 - loss: 0.9310 - val_accuracy: 0.6505 - val_loss: 1.0119
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6884 - loss: 0.9000 - val_accuracy: 0.6570 - val_loss: 0.9888
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6973 - loss: 0.8746 - val_accuracy: 0.6630 - val_loss: 0.9808
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7011 - loss: 0.8599 - val_accuracy: 0.6608 - val_loss: 0.9902
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7104 - loss: 0.8340 - val_accuracy: 0.6543 - val_loss: 1.0108
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7218 - loss: 0.8113 - val_accuracy: 0.6641 - val_loss: 0.9692
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7296 - loss: 0.7963 - val_accuracy: 0.6562 - val_loss: 1.0226
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7308 - loss: 0.7736 - val_accuracy: 0.6582 - val_loss: 1.0123

# %% [markdown]
# Finally, pick a better optimizer. And re-train your model. You'll know you have a reasonable model with a reasonable loss funciton and optimizer if your final training accuracy ends up in the 80s (or possibly higher).
#
# *A hint: your model may want to learn adaptively.*

# %%
OPTIMIZER = 'adam'

# Compile the model
model.compile(optimizer=OPTIMIZER,
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6815 - loss: 0.9068 - val_accuracy: 0.6667 - val_loss: 0.9762
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7152 - loss: 0.8191 - val_accuracy: 0.6792 - val_loss: 0.9356
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7378 - loss: 0.7499 - val_accuracy: 0.6818 - val_loss: 0.9373
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7605 - loss: 0.6897 - val_accuracy: 0.6858 - val_loss: 0.9202
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7760 - loss: 0.6442 - val_accuracy: 0.6749 - val_loss: 0.9765
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7972 - loss: 0.5922 - val_accuracy: 0.6914 - val_loss: 0.9500
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8087 - loss: 0.5497 - val_accuracy: 0.7013 - val_loss: 0.9216
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8201 - loss: 0.5187 - val_accuracy: 0.6991 - val_loss: 0.9697
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8303 - loss: 0.4894 - val_accuracy: 0.6784 - val_loss: 1.0971
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8383 - loss: 0.4602 - val_accuracy: 0.6812 - val_loss: 1.1076
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8531 - loss: 0.4258 - val_accuracy: 0.6934 - val_loss: 1.0528
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8618 - loss: 0.3978 - val_accuracy: 0.6939 - val_loss: 1.0664
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8671 - loss: 0.3804 - val_accuracy: 0.6883 - val_loss: 1.1543
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8732 - loss: 0.3590 - val_accuracy: 0.6876 - val_loss: 1.1728
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8854 - loss: 0.3292 - val_accuracy: 0.6763 - val_loss: 1.2256
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8915 - loss: 0.3086 - val_accuracy: 0.6834 - val_loss: 1.2637
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9008 - loss: 0.2827 - val_accuracy: 0.6759 - val_loss: 1.3238
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9000 - loss: 0.2813 - val_accuracy: 0.6845 - val_loss: 1.3399
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9073 - loss: 0.2599 - val_accuracy: 0.6795 - val_loss: 1.4495
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9106 - loss: 0.2499 - val_accuracy: 0.6778 - val_loss: 1.4982
